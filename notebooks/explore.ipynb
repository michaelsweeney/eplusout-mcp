# %%
import os
import pandas as pd
os.chdir(r'C:\code\ai-mcp\mcp-eplus-outputs')

from src.model_data import ModelMap, read_or_initialize_model_map

from src import model_data

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
model_dir = r'C:\code\ai-mcp\mcp-eplus-outputs\eplus_files'

d = model_data.initialize_model_map_from_directory(model_dir)
# Out:
# writing to cache: C:\code\ai-mcp\mcp-eplus-outputs\mcp_cache\modelmap.pickle

# %%
mobj = model_data.read_or_initialize_model_map(model_dir)

model_summary_table = pd.DataFrame([x.model_dump(mode='json') for x in mobj.models])
# Out:
# reading cached file C:\code\ai-mcp\mcp-eplus-outputs\mcp_cache\modelmap.pickle

# %%
model_summary_table.city.unique()
# Out:
# array(['Buffalo', 'Tampa'], dtype=object)

# %%
mobj.models
# Out:
# [ModelFileData(codename='ASHRAE901', prototype='HotelLarge', codeyear='STD2025', city='Buffalo', label='gshp', model_id='ASHRAE901|HotelLarge|STD2025|Buffalo|gshp', epjson_data=EpJsonFileData(file_path='C:\\code\\ai-mcp\\mcp-eplus-outputs\\eplus_files\\ASHRAE901_HotelLarge_STD2025_Buffalo_SkipEC_gshp.epJSON', data=None), sql_data=SqlFileData(file_path='C:\\code\\ai-mcp\\mcp-eplus-outputs\\eplus_files\\ASHRAE901_HotelLarge_STD2025_Buffalo_SkipEC_gshp.sql', sql_timeseries=None, sql_tables=None), html_data=HtmlFileData(file_path='C:\\code\\ai-mcp\\mcp-eplus-outputs\\eplus_files\\ASHRAE901_HotelLarge_STD2025_Buffalo_SkipEC_gshp.table.htm', data=None, report_names=None)),
# ...

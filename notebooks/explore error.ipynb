# %%
import os
import pandas as pd
os.chdir(r'C:\code\ai-mcp\mcp-eplus-outputs')
import plotly.express as px

from src.model_data import ModelMap, read_or_initialize_model_map, initialize_model_map_from_directory
 
from src import model_data
import src

from src import server
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
model_dir = r'C:\code\ai-mcp\mcp-eplus-outputs\eplus_files\prescriptive_variability_sample'
error_dir = r'C:\code\ai-mcp\mcp-eplus-outputs\eplus_files\forced_error\error\error_sanitize'


d = initialize_model_map_from_directory(error_dir)

d.models[0].get_associated_files_by_type('err')
# Out:
# writing to cache: C:\code\ai-mcp\mcp-eplus-outputs\mcp_cache\modelmap.pickle
# ...

# %%
server.get_error_file
# Out:
# <function src.server.get_error_file(id: 'str') -> 'list[dict]'>

# %%
os.path.exists(
    r'C:\code\ai-mcp\mcp-eplus-outputs\eplus_files\forced_error\error\error_sanitize\ASHRAE901_HotelLarge_STD2025_Buffalo_SkipEC_pvav_awhp.dd.csv'
)
# pd.read_csv(
#     r'C:\code\ai-mcp\mcp-eplus-outputs\eplus_files\forced_error\error\error_sanitize\ASHRAE901_HotelLarge_STD2025_Buffalo_SkipEC_pvav_awhp.dd.csv'
# )
# Out:
# True

# %%
server.get_error_file(server.get_available_models()[0]['model_id'])
# Out:
# reading model map
# reading cached file C:\code\ai-mcp\mcp-eplus-outputs\mcp_cache\modelmap.pickle
# reading model map
# reading cached file C:\code\ai-mcp\mcp-eplus-outputs\mcp_cache\modelmap.pickle
# ['Program Version,EnergyPlus, Version 24.1.0-9d7789a3ac, YMD=2025.09.29 10:40,\n',
#  '   ************* Beginning Zone Sizing Calculations\n',
#  '   ** Warning ** Weather file location will be used rather than entered (IDF) Location object.\n',
#  '   **   ~~~   ** ..Location object=BUFFALO.NIAGARA.INTL.AP_NY_USA WMO=725280\n',
#  '   **   ~~~   ** ..Weather File Location=Denver Centennial  Golden   Nr CO USA TMY3 WMO#=724666\n',
#  '   **   ~~~   ** ..due to location differences, Latitude difference=[3.20] degrees, Longitude difference=[26.44] degrees.\n',
#  '   **   ~~~   ** ..Time Zone difference=[2.0] hour(s), Elevation difference=[750.70] percent, [1614.00] meters.\n',
# ...
